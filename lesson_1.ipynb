# %% [markdown]
# # Lesson 1
# **this is a sentence, it is a nice day today.**

# %%
print("HELLO WORLD")
# Out:
# HELLO WORLD

# %%
import matplotlib.pyplot as plt

x1=[111,10,40,19]
y=[1,20,80,1]

plt.plot(x1,y)#used for ploting line
plt.ylabel("dogs")#ylabel is for naming y
plt.xlabel("cats")#xlabel is for naming x 
plt.title("ANIMALS")#title is used for naming graph
# Out:
# Text(0.5, 1.0, 'ANIMALS')

# %%
jojo=[8,23,45,4]


ax.hist(x, bins=8, linewidth=0.5, edgecolor="black")#
plt.hist(jojo)#this part is pokitng hist as graph
# Out:
# (array([2., 0., 0., 0., 1., 0., 0., 0., 0., 1.]),
#  array([ 4. ,  8.1, 12.2, 16.3, 20.4, 24.5, 28.6, 32.7, 36.8, 40.9, 45. ]),
#  <BarContainer object of 10 artists>)

# %%
fig, ax = plt.subplots()
ax.pie(x,radius=3, center=(4, 4),
       wedgeprops={"linewidth": 1, "edgecolor": "black"}, frame=True)
# Out:
# ([<matplotlib.patches.Wedge at 0x1541e6c20>,
# ...
#  [Text(7.299025435165816, 4.080194626559399, ''),
#   Text(7.294012931565762, 4.198692744400835, ''),
#   Text(7.288365186007991, 4.2768653164458, ''),
#   Text(7.281778379541917, 4.3463100743138, ''),
#   Text(7.270342877486048, 4.441426623207395, ''),
#   Text(7.259803252898335, 4.513500489185198, ''),
#   Text(7.244719736922492, 4.601492999814328, ''),
#   Text(7.221127318198557, 4.717174176860106, ''),
#   Text(7.20002603200959, 4.806122443839001, ''),
#   Text(7.173862679256949, 4.903656844836526, ''),
#   Text(7.138184992379587, 5.02068357173197, ''),
#   Text(7.1096847293079435, 5.104473125209021, ''),
#   Text(7.090792409883711, 5.156288147048668, ''),
#   Text(7.059432935983392, 5.236879181739285, ''),
#   Text(7.015010649918762, 5.341532996566409, ''),
#   Text(6.972842318434507, 5.432553157730961, ''),
#   Text(6.9391085531834245, 5.500546871178652, ''),
#   Text(6.901846073790299, 5.571397264865836, ''),
# ...
