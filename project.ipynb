# %%
import pandas as pd
import matplotlib.pyplot as plt
df = pd.read_csv("NYCLIB.csv")
df.head()

#this part of ipynb file is used to import stuff which will be needed for later use such as csv file,matplotlib and pandas.
# Out:
#   Boro/Central Library                       Network                 Branch  \
# 0                Bronx  Bronx Library Center Network               Allerton
# 1                Bronx  Bronx Library Center Network                Belmont
# 2                Bronx  Bronx Library Center Network  Bronx  Library Center
# 3                Bronx  Bronx Library Center Network         Francis Martin
# 4                Bronx  Bronx Library Center Network        Grand Concourse
#
#    ADULT Program  ADULT Attendance  YOUNG ADULT Program  \
# 0           25.0             250.0                 37.0
# 1          226.0            2795.0                186.0
# 2          449.0           15179.0                201.0
# 3            7.0             108.0                 44.0
# 4          228.0            1841.0                220.0
#
#    YOUNG ADULT Attendance  JUVENILE Program  JUVENILE Attendance  \
# 0                   420.0             183.0               4714.0
# 1                  2166.0             352.0               6792.0
# 2                  4324.0             379.0              13069.0
# 3                   506.0             206.0               3805.0
# 4                  2450.0             349.0               8976.0
#
#    OUTREACH SERVICES Program  ...   TOTAL Attendance  \
# 0                        1.0  ...             5401.0
# 1                       62.0  ...            12493.0
# 2                      303.0  ...            40723.0
# 3                       18.0  ...             5064.0
# 4                      368.0  ...            18364.0
#
#     REFERENCE TRANSACTIONS Adult   REFERENCE TRANSACTIONS Young Adult  \
# 0                        75595.0                              32253.0
# 1                        96980.0                              93028.0
# 2                       254384.0                              78494.0
# 3                        27469.0                               8112.0
# 4                        44460.0                              17810.0
#
#     REFERENCE TRANSACTIONS Juvenile   REFERENCE TRANSACTIONS  \
# 0                           38038.0                 145886.0
# 1                           94263.0                 284271.0
# 2                          173134.0                 506012.0
# 3                           11609.0                  47190.0
# 4                           17238.0                  79508.0
#
#    CIRCULATION Adult  CIRCULATION Young Adult  CIRCULATION Juvenile  \
# 0            62767.0                  20191.0               47961.0
# 1            61924.0                  14614.0               42140.0
# 2           354231.0                  75239.0              184508.0
# 3            43431.0                  15379.0               37966.0
# 4            77381.0                  21413.0               51671.0
#
#    CIRCULATION  Weekly Hours of Public Service
# 0     130919.0                            46.0
# 1     118678.0                            46.0
# 2     613978.0                            78.0
# 3      96776.0                            46.0
# 4     150465.0                            50.0
#
# [5 rows x 22 columns]

# %%
graph1 = df.groupby('Boro/Central Library')['CIRCULATION Young Adult'].sum()#colects data from csv file about circulation of Young adults.

# %%
bar_colors = ['tab:red', 'tab:blue', 'tab:pink', 'tab:orange','tab:purple','tab:green']
graph1.plot(kind="bar",ylabel='CIRCULATION Young Adult',color=bar_colors)

plt.xticks(rotation=65)#xticks rotates names of x values in ordert to make it easy to read
# Out:
# (array([0, 1, 2, 3, 4, 5]),
#  [Text(0, 0, 'Bronx'),
#   Text(1, 0, 'CENTRAL LIBRARY UNITS'),
#   Text(2, 0, 'Manhattan'),
#   Text(3, 0, 'Other'),
#   Text(4, 0, 'Staten Island'),
#   Text(5, 0, 'System')])

# %% [markdown]
# This graph represents amount of young adults circulating in library in different parts of NYC.
# On this graph you can see that more young adults use librarys in Manhatta and Bronx then in Staten Island.

# %%
graph2 = df.groupby('Boro/Central Library')['CIRCULATION Adult'].sum()#colects data from csv file about circulation of adults.

# %%
bar_colors = ['tab:red', 'tab:blue', 'tab:pink', 'tab:orange','tab:purple','tab:green']
graph2.plot(kind="bar",ylabel='CIRCULATION Adult',color=bar_colors)
plt.xticks(rotation=65)#xticks rotates names of x values in ordert to make it easy to read
# Out:
# (array([0, 1, 2, 3, 4, 5]),
#  [Text(0, 0, 'Bronx'),
#   Text(1, 0, 'CENTRAL LIBRARY UNITS'),
#   Text(2, 0, 'Manhattan'),
#   Text(3, 0, 'Other'),
#   Text(4, 0, 'Staten Island'),
#   Text(5, 0, 'System')])

# %% [markdown]
# This graph is simmular to priveos one, but now it shows amout of adults using librarys.
# Same as priveous graph you can see more adults are using librarys in Manhattan but adults are using more librarys of Central library units than Bronx.
